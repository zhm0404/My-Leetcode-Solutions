# %% [markdown]
# Given an array of integers nums sorted in non-decreasing order, find the starting and ending position of a given target value.
#
# If target is not found in the array, return [-1, -1].
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [5,7,7,8,8,10], target = 8
# Output: [3,4]
# Example 2:
#
# Input: nums = [5,7,7,8,8,10], target = 6
# Output: [-1,-1]
# Example 3:
#
# Input: nums = [], target = 0
# Output: [-1,-1]
#
#
# Constraints:
#
# 0 <= nums.length <= 105
# -109 <= nums[i] <= 109
# nums is a non-decreasing array.
# -109 <= target <= 109

# %%
from typing import List
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        if len(nums) == 0:
            return [-1, -1]

        beforeTarget = None # Initialize the index of the largest element before target
        afterTarget = None # Initialize the index of the smallest element after target
        
        # Find the largest element < target
        start = 0
        end = len(nums) - 1

        while start <= end:
            point = (start + end) //2
            if nums[point] < target:
                beforeTarget = point
                start = point + 1
            else:
                end = point - 1

        # Find the smallest element > target
        start = 0
        end = len(nums) - 1

        while start <= end:
            point = (start + end) //2
            if nums[point] > target:
                afterTarget = point
                end = point - 1
            else:
                start = point + 1

        
        # if all elements are equal to target
        if beforeTarget is None and afterTarget is None:
            return [0, len(nums)-1]

        # if all elements are <= or >= target
        if beforeTarget is None:
            if afterTarget == 0:
                return [-1, -1]
            else:
                return [0, afterTarget - 1]
        if afterTarget is None:
            if beforeTarget == len(nums) - 1:
                return [-1, -1]
            else:
                return [beforeTarget + 1, len(nums) - 1]
        
        # if no elements are equal to target
        if beforeTarget + 1 == afterTarget:
            return [-1, -1]
        else:
            return [beforeTarget + 1, afterTarget - 1]

# Another solution
    def searchRange2(self, nums: List[int], target: int) -> List[int]:
        
        # search for smallest num >= x
        def search(x):
            lo, hi = 0, len(nums)           
            while lo < hi:
                mid = (lo + hi) // 2
                if nums[mid] < x:
                    lo = mid+1
                else:
                    hi = mid  
                # When the loop ends, we will have lo = hi
                # In the last step we will have lo = hi. At this moment, lo will be the index after some largest possible element which is < x
                # lo could be len(nums) (when all elements are < x)
                # that's why we initialize hi with len(nums)
                # Also, the loop will not be skipped if we only have one element
            return lo
        
        lo = search(target)
        hi = search(target+1)-1
        
        if lo <= hi:
            return [lo, hi]
                
        return [-1, -1]
s = Solution()
s.searchRange(nums=[8,8,9,10], target=8)
# Out:
# [0, 1]
