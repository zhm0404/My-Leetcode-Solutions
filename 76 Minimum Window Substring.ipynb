# %% [markdown]
# Given two strings s and t of lengths m and n respectively, return the minimum window substring of s such that every character in t (including duplicates) is included in the window. If there is no such substring, return the empty string "".
#
# The testcases will be generated such that the answer is unique.
#
#
#
# Example 1:
#
# Input: s = "ADOBECODEBANC", t = "ABC"
# Output: "BANC"
# Explanation: The minimum window substring "BANC" includes 'A', 'B', and 'C' from string t.
#
# Example 2:
#
# Input: s = "a", t = "a"
# Output: "a"
# Explanation: The entire string s is the minimum window.
#
# Example 3:
#
# Input: s = "a", t = "aa"
# Output: ""
# Explanation: Both 'a's from t must be included in the window.
# Since the largest window of s only has one 'a', return empty string.
#
#
# Constraints:
#
# m == s.length
# n == t.length
# 1 <= m, n <= 105
# s and t consist of uppercase and lowercase English letters.

# %%
import collections


class Solution:
    def minWindow(self, s: str, t: str) -> str:
        if len(s) < len(t):
            return ""
        target = {}
        for char in t:
            target[char] = 1 + target.get(char, 0)
        window  = {}

        length = float('inf')
        res = ""

        have = len(window)
        need = len(target)

        start = 0
        for r in range(len(s)):
            char = s[r]
            window[char] = 1 + window.get(char, 0)
            if char in target and window[char] == target[char]:
                have += 1
            
            #check if we have the correct window
            while have == need:
                # update the result, even if it's not the minimum window
                if r - start + 1 < length:
                    res = s[start:r+1]
                    length = r - start + 1
                # update the window
                window[s[start]] -= 1
                if s[start] in target and window[s[start]] < target[s[start]]:
                    have -= 1
                start += 1
        
        return res

# Optimal
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        if len(s) < len(t):
            return ""
        needstr = collections.defaultdict(int)
        for ch in t:
            needstr[ch] += 1
        needcnt = len(t)
        res = (0, float('inf'))

        start = 0
        for end, ch in enumerate(s):
            # track needcnt until needcnt == 0
            if needstr[ch] > 0:
                needcnt -= 1
            needstr[ch] -= 1

            # check if we have the correct window
            if needcnt == 0:
                # get the minimum window
                while True:
                    tmp = s[start]
                    if needstr[tmp] == 0:
                        break
                    needstr[tmp] += 1
                    start += 1
                #update the result
                if end - start < res[1] - res[0]:
                    res = (start, end)
                
                #update the window
                needstr[s[start]] += 1
                needcnt += 1
                start += 1
        return '' if res[1] > len(s) else s[res[0]:res[1]+1]
        
# class Node:
#     def __init__(self, char:str, index:int, next=None) -> None:
#         self.char = char
#         self.index = index
#         self.next = next

# class LinkedList:
#     def __init__(self):
#         self.head = Node("-1",-1)
#         self.end = Node("-2",-2)
#         self.head.next = self.end
#         self.secondToEnd = self.head
    
#     def append(self, node: Node):
#         self.secondToEnd.next = node
#         node.next = self.end
#         self.secondToEnd = node
    
#     def removeTop(self):
#         top = self.head.next
#         self.head.next = top.next
#         if(self.secondToEnd==top):
#             self.secondToEnd = self.head
#         del top
    
#     def display(self):
#         current = self.head.next
#         while current.next!=None:
#             print(current.char, current.index, end=" ")
#             current = current.next
